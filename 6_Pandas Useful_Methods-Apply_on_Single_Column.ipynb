# %%
import numpy as np
import pandas as pd

# %%
str(12356568689)[-4:]
# Out:
# '8689'

# %%
def last_four(num) :
    return str(num)[-4:]

# %%
last_four(83987238479)
# Out:
# '8479'

# %%
df['last_four'] = df['CC Number'].apply(last_four)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-03e86b2407da> in <module>
# ----> 1 df['last_four'] = df['CC Number'].apply(last_four)
#
# NameError: name 'df' is not defined

# %%
def yelp(price):
    if price > 10:
        return '&'
    elif price >= 10 and price < 30 :
        return '&&'
    else :
        return '&&&'

# %%
df['yelp'] = df['total_bill'].apply(yelp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-716d213d80b4> in <module>
# ----> 1 df['yelp'] = df['total_bill'].apply(yelp)
#
# NameError: name 'df' is not defined

# %%
#df.apply(FONKSİYON) metodu ile 
#table içindeki bir sutunun tamamına aynı anda
#fonksiyonu uygulamış oluyoruz.

# %%
#df['fonksiyon'] = df.apply(FONKSİYON) şeklinde yeni
#fonksiyonumuzu uyguladığımız sütunu 'fonksiyon' olarak eşitlersek
#mevcut table üzerinde 'fonksiyon' adında yeni bir sütun 
#oluşturmuş oluyoruz.
